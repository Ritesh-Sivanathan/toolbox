# %%
from mathematics.fun.sierpinski_triangle import Sierpinski_Triangle

Sierpinski_Triangle()
# Out:
# [[0.846, 0.145],
#  [0.525, 0.346],
#  [0.165, 0.333],
#  [0.069, 0.305],
#  [0.159, 0.004],
#  [0.5700000000000001, 0.271],
#  [0.192, 0.752],
#  [0.938, 0.05],
#  [0.112, 0.763],
#  [0.096, 0.65],
#  [0.098, 0.767],
#  [0.317, 0.542],
#  [0.084, 0.667],
#  [0.502, 0.025],
#  [0.136, 0.052],
#  [0.024, 0.195],
#  [0.207, 0.759],
#  [0.798, 0.13],
#  [0.013, 0.22],
#  [0.103, 0.521],
#  [0.876, 0.08],
#  [0.406, 0.589],
#  [0.258, 0.524],
#  [0.004, 0.985],
#  [0.579, 0.011],
#  [0.044, 0.563],
#  [0.5680000000000001, 0.383],
#  [0.192, 0.784],
#  [0.067, 0.761],
#  [0.393, 0.07],
#  [0.033, 0.707],
#  [0.043, 0.891],
#  [0.525, 0.382],
#  [0.946, 0.035],
#  [0.565, 0.385],
#  [0.7929999999999999, 0.081],
#  [0.02, 0.447],
#  [0.525, 0.439],
#  [0.379, 0.548],
#  [0.128, 0.5700000000000001],
#  [0.146, 0.347],
#  [0.696, 0.053],
#  [0.767, 0.133],
#  [0.8300000000000001, 0.004],
#  [0.048, 0.196],
#  [0.033, 0.569],
#  [0.512, 0.363],
#  [0.611, 0.008],
#  [0.007, 0.891],
# ...
